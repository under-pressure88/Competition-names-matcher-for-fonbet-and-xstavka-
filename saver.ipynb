# %%
import pandas as pd

# %%
df_xst=pd.read_csv('xstavka_names.csv')

# %%
df_xst.iloc[5:33]
# Out:
#     Unnamed: 0                  Player 1                           Player 2  \
# 5            0     Internazionale Milano                             Getafe
# 6            1          Lautaro Martinez                  Jaime Mata Arnaiz
# 7            2         Manchester United                          LASK Linz
# 8            3                Cittadella                   Frosinone Calcio
# 9            4             NK Istra 1961                            Orijent
# 10           5                Al-Hussein                          Al-Sareeh
# 11           6           Moghreb Tetouan                    Raja Casablanca
# 12           7        Vojvodina Novi Sad                          Cukaricki
# 13           8                    Murici  Agremiacao Sportiva Arapiraquense
# 14           9              Concordia AC                            Tubarao
# 15          10                  Tombense       Associacao Atletica Caldense
# ...

# %%
df_xst.iloc[236:239]
# Out:
#      Unnamed: 0        Player 1       Player 2      1     X      2      O  \
# 236           0  Calgary Flames   Dallas Stars   5.06  4.35    1.6  2.344
# 237           1     Devils Team  Penguins Team   2.04  4.39   2.76   1.39
# 238           2  Severstal Team    Dinamo Team  2.395  6.25  1.984   1.73
#
#      Total      U     1*  ...     2* O*  IT1 U*  O*.1  IT2  U*.1 1*.1 2*.1 X*
# 236   1.22   1.17  2.096  ...   1.77  -  +1-  -  1.85  1.5  1.95    -    -  -
# 237   1.17   1.69   1.72  ...  2.115  -    0  -  1.93    3  1.88    -    -  -
# 238  1.085  1.504  1.945  ...  1.856  -    0  -  1.91  3.5  1.89    -    -  -
#
# [3 rows x 21 columns]

# %%
df_xst.iloc[239:258].to_csv('xstavka_names39.csv')
#df_xstavka.to_csv('xstavka_names25.csv', mode='a', header=False)
